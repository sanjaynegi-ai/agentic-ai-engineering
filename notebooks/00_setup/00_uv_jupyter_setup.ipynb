# %% [markdown]
# # uv and Jupyter setup
#
# ## Learning goals
# - Create a reproducible Python 3.12 environment
# - Register and remove a Jupyter kernel

# %% [markdown]
# `uv` resolves, locks, and runs the course environment. Use `uv run` to avoid ambiguity about which interpreter is active.

# %% [markdown]
# ## Mental model
#
# ```mermaid
# flowchart LR
#   A[Input] --> B[Runtime decision]
#   B --> C[Tool or model]
#   C --> D[Validated result]
# ```

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
commands = ['uv init', 'uv sync', 'uv add openai', 'uv run jupyter lab']
for command in commands:
    print(command)

# %% [markdown]
# ## Failure case and improvement
#
# Identify what can fail: malformed output, unavailable services, unsafe input, repeated actions, or exhausted budgets. Validate at the runtime boundary, expose the error, and stop predictably.

# %% [markdown]
# ## Exercise
#
# Register the kernel, inspect it with `jupyter kernelspec list`, then document the uninstall command for your OS.

# %% [markdown]
# ## Summary
#
# The model proposes; the surrounding program validates, executes, observes, and decides when to stop. Frameworks package these same ingredients rather than replacing them.
